# %%
# %load_ext autoreload
# %autoreload 2
# Init everything here
#!python
# -*- coding: utf-8 -*-

import os
import sys

sys.path.insert(0, os.path.join(os.getcwd(), ".."))
from src import boot, ui, vision

FARM_INSTANCE = "farm1"
MAIN_INSTANCE = "main"
# instance = FARM_INSTANCE
instance = FARM_INSTANCE

boot.init_instance(instance, rok_ready=True)
# Out:
# [INFO] 2025-09-22 11:40:57 -
# -------------------- INIT START --------------------
# [2025-09-22 11:40:57] Instance name: 'farm1'
# [INFO] 2025-09-22 11:40:57 - Refreshing ADB server...
# [INFO] 2025-09-22 11:40:57 - Normal mode: restarting ADB server
# [INFO] 2025-09-22 11:41:02 - ADB server refreshed.
# [DEBUG] 2025-09-22 11:41:02 - Init LDInstance
# [DEBUG] 2025-09-22 11:41:03 - Instance 'farm1' already started
# [DEBUG] 2025-09-22 11:41:03 - Verify adb connection
# [DEBUG] 2025-09-22 11:41:03 - Init ADBInstance with LDPInstance farm1
# [DEBUG] 2025-09-22 11:41:03 - _pre_running_devices: {'emulator-5554'}
# [DEBUG] 2025-09-22 11:41:03 - Instance already initiated
# [INFO] 2025-09-22 11:41:03 - Connected adb emulator-5554 with instance farm1
# [INFO] 2025-09-22 11:41:04 - -----------------INIT DONE-----------------

# %%
# capture full screen
vision.image.screenshot()
# Out:
# [DEBUG] 2025-09-22 11:22:44 - Saved screenshot: C:\Users\thanl\OneDrive\Documents\rok_pymacro2\tmp\logs\2f1e9be1-8775-4f3d-9cc9-09eb297fc4cc\images\screen_112244.png

# %%
# capture partially
btn = ui.MenuMain.CITY_INFO_ICON
vision.image.get_image_from_rect(btn, save=True)

# %%
from src import task

task.Collect().collect_alliance_rss()
# Out:
# [DEBUG] 2025-09-22 11:46:59 - This should be triggered only in the morning
# [INFO] 2025-09-22 11:46:59 - Open MenuAlliance
# [DEBUG] 2025-09-22 11:47:02 - Sub menu already expanded
# [INFO] 2025-09-22 11:47:02 - Open MenuAlliance
# [DEBUG] 2025-09-22 11:47:02 - Click Alliance(1386,990)
# [INFO] 2025-09-22 11:47:05 - Open MenuAlliance
# [DEBUG] 2025-09-22 11:47:05 - Menu Alliance already opened
# [INFO] 2025-09-22 11:47:05 - Open MenuAllianceTerritory
# [DEBUG] 2025-09-22 11:47:05 - Click TERRITORY(1257,640)
# [DEBUG] 2025-09-22 11:47:07 - Click CLAIM(1483,213)
# Time remaining: 0.1s
# [INFO] 2025-09-22 11:47:09 - Close MenuAllianceTerritory
# [INFO] 2025-09-22 11:47:10 - Close MenuAlliance
